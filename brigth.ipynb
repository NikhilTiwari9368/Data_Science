# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import regex

# %%
data = pd.read_csv('BrightCHAMP.csv')

# %%
data
# Out:
#                             Email  Employee ID  First Name  Last Name  City  \
# 0         john.storm@gotrocks.net       9345.0         NaN        NaN   NaN
# 1          john.johnson@wahoo.com       6875.0         NaN        NaN   NaN
# 2        debby.powers@jeemail.com       6431.0         NaN        NaN   NaN
# 3      joe.byethen@whitehouse.gov       6076.0         NaN        NaN   NaN
# 4          stephanie.diaz@msm.org       8198.0         NaN        NaN   NaN
# 5           donald.gump@wahoo.com       7220.0         NaN        NaN   NaN
# 6        sarah.cohen@coldmail.com       8638.0         NaN        NaN   NaN
# 7  vladimir.lupin@kremlinmail.com       8187.0         NaN        NaN   NaN
# 8                             NaN          NaN         NaN        NaN   NaN
#
#    Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll  \
# 0        NaN          NaN  £10,088              NaN            NaN
# 1        NaN          NaN  £11,176              NaN            NaN
# ...

# %%
data.isnull().sum()
# Out:
# Email              1
# Employee ID        1
# First Name         9
# Last Name          9
# City               9
# Hire Date          9
# Hiring Year        9
# Payroll            1
# Payroll Raise %    9
# Raise Payroll      9
# Unnamed: 10        9
# Email.1            0
# Hire date          0
# City.1             0
# Unnamed: 14        9
# Year               6
# Pay Raise          6
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# Email              8
# Employee ID        8
# First Name         0
# Last Name          0
# City               0
# Hire Date          0
# Hiring Year        0
# Payroll            8
# Payroll Raise %    0
# Raise Payroll      0
# Unnamed: 10        0
# Email.1            9
# Hire date          9
# City.1             8
# Unnamed: 14        0
# Year               3
# Pay Raise          3
# dtype: int64

# %%
data.nunique().sum()
# Out:
# 56

# %%
data
# Out:
#                             Email  Employee ID  First Name  Last Name  City  \
# 0         john.storm@gotrocks.net       9345.0         NaN        NaN   NaN
# 1          john.johnson@wahoo.com       6875.0         NaN        NaN   NaN
# 2        debby.powers@jeemail.com       6431.0         NaN        NaN   NaN
# 3      joe.byethen@whitehouse.gov       6076.0         NaN        NaN   NaN
# 4          stephanie.diaz@msm.org       8198.0         NaN        NaN   NaN
# 5           donald.gump@wahoo.com       7220.0         NaN        NaN   NaN
# 6        sarah.cohen@coldmail.com       8638.0         NaN        NaN   NaN
# 7  vladimir.lupin@kremlinmail.com       8187.0         NaN        NaN   NaN
# 8                             NaN          NaN         NaN        NaN   NaN
#
#    Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll  \
# 0        NaN          NaN  £10,088              NaN            NaN
# 1        NaN          NaN  £11,176              NaN            NaN
# ...

# %%
data['Email']
# Out:
# 0           john.storm@gotrocks.net
# 1            john.johnson@wahoo.com
# 2          debby.powers@jeemail.com
# 3        joe.byethen@whitehouse.gov
# 4            stephanie.diaz@msm.org
# 5             donald.gump@wahoo.com
# 6          sarah.cohen@coldmail.com
# 7    vladimir.lupin@kremlinmail.com
# 8                               NaN
# Name: Email, dtype: object

# %%
def email_splitter(Email):
    username = Email.split('.')[0]
    lastname = Email.split('.')[1]
    

    print('Username : ', username)print('remove : ' , remove)

email_splitter('john.storm@gotrocks.net')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 10>()
#       7     print('lastname  : ', lastname)
#       8     print('remove : ' , remove)
# ---> 10 email_splitter('john.storm@gotrocks.net')
#
# Input In [27], in email_splitter(Email)
#       2 username = Email.split('.')[0]
#       3 lastname = Email.split('.')[1]
# ----> 4 remove = Email.remove(' @ ')[2]
#       6 print('Username : ', username)
#       7 print('lastname  : ', lastname)
#
# AttributeError: 'str' object has no attribute 'remove'

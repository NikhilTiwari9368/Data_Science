# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("ipl-matches.csv")

# %%
data.sample(3)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 933   335998      Delhi  2008-04-30  2007/08          17
# 508   734017  Ahmedabad  2014-05-19     2014          44
# 116  1254075     Mumbai  2021-04-24     2021          18
#
#                      Team1                        Team2  \
# 933       Delhi Daredevils  Royal Challengers Bangalore
# 508       Rajasthan Royals               Mumbai Indians
# 116  Kolkata Knight Riders             Rajasthan Royals
#
#                             Venue                   TossWinner TossDecision  \
# 933              Feroz Shah Kotla  Royal Challengers Bangalore        field
# 508  Sardar Patel Stadium, Motera               Mumbai Indians          bat
# 116      Wankhede Stadium, Mumbai             Rajasthan Royals        field
#
#     SuperOver       WinningTeam    WonBy  Margin method Player_of_Match  \
# 933         N  Delhi Daredevils     Runs    10.0    NaN      GD McGrath
# 508         N    Mumbai Indians     Runs    25.0    NaN      MEK Hussey
# 116         N  Rajasthan Royals  Wickets     6.0    NaN       CH Morris
#
#                                           Team1Players  \
# 933  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'Shoaib ...
# 508  ['KK Nair', 'UBT Chand', 'SR Watson', 'SV Sams...
# 116  ['N Rana', 'Shubman Gill', 'RA Tripathi', 'SP ...
#
#                                           Team2Players        Umpire1  \
# 933  ['P Kumar', 'W Jaffer', 'LRPL Taylor', 'JH Kal...      Aleem Dar
# 508  ['MEK Hussey', 'LMP Simmons', 'KA Pollard', 'R...         S Ravi
# 116  ['JC Buttler', 'YBK Jaiswal', 'SV Samson', 'S ...  Navdeep Singh
#
#        Umpire2
# 933  I Shivram
# 508  RJ Tucker
# 116     S Ravi

# %%
data.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %%
data.tail(3)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 947             Delhi Daredevils       Rajasthan Royals
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 947          bat         N       Delhi Daredevils  Wickets     9.0    NaN
# 948          bat         N    Chennai Super Kings     Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders     Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 947     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players    Umpire1  \
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...  Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...  MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...  Asad Rauf
#
#             Umpire2
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen

# %%
import seaborn as sns

# %%
data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(data['SepalLength'],data['PetalLength'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\python3.9\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\python3.9\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\python3.9\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SepalLength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 plt.scatter(data['SepalLength'],data['PetalLength'])
#
# File C:\python3.9\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\python3.9\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'SepalLength'
